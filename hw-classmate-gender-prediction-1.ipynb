# /kaggle/input/bdm-2021-face/622110154_3_0.jpg
# /kaggle/input/bdm-2021-face/622110134_2_0.jpg
# /kaggle/input/bdm-2021-face/622110225_1_0.jpg
# /kaggle/input/bdm-2021-face/622110174_1_1.jpg
# /kaggle/input/bdm-2021-face/622110207_4_0.jpg
# /kaggle/input/bdm-2021-face/622110140_3_0.jpg
# /kaggle/input/bdm-2021-face/622110137_1_0.jpg
# /kaggle/input/bdm-2021-face/622110206_1_0.jpg
# /kaggle/input/bdm-2021-face/612110186_3_1.jpg
# /kaggle/input/bdm-2021-face/622110225_3_0.jpg
# /kaggle/input/bdm-2021-face/622110207_3_0.jpg
# /kaggle/input/bdm-2021-face/622110172_4_0.jpg
# /kaggle/input/bdm-2021-face/612110234_2_0.jpg
# /kaggle/input/bdm-2021-face/612110234_3_0.jpg
# /kaggle/input/bdm-2021-face/612110174_3_0.jpg
# /kaggle/input/bdm-2021-face/622110222_3_1.jpg
# /kaggle/input/bdm-2021-face/622110225_2_0.jpg
# /kaggle/input/bdm-2021-face/602110108_2_0.jpg
# /kaggle/input/bdm-2021-face/622110154_4_0.jpg
# /kaggle/input/bdm-2021-face/622110222_1_1.jpg
# /kaggle/input/bdm-2021-face/622110210_4_0.jpg
# /kaggle/input/bdm-2021-face/622110206_3_0.jpg
# /kaggle/input/bdm-2021-face/612110165_4_0.jpg
# /kaggle/input/bdm-2021-face/622110240_3_0.jpg
# /kaggle/input/bdm-2021-face/612110186_4_1.jpg
# /kaggle/input/bdm-2021-face/622110210_3_0.jpg
# /kaggle/input/bdm-2021-face/612110159_4_0.jpg
# /kaggle/input/bdm-2021-face/622110225_4_0.jpg
# /kaggle/input/bdm-2021-face/612110165_2_0.jpg
# /kaggle/input/bdm-2021-face/622110240_2_0.jpg
# /kaggle/input/bdm-2021-face/612110159_1_0.jpg
# /kaggle/input/bdm-2021-face/622110172_2_0.jpg
# /kaggle/input/bdm-2021-face/622110206_2_0.jpg
# /kaggle/input/bdm-2021-face/612110174_2_0.jpg
# /kaggle/input/bdm-2021-face/622110209_2_1.jpg

# %%
import glob
filename = glob.glob("/kaggle/input/bdm-2021-face/*.*")
filename[0].split("_")
# Out:
# ['/kaggle/input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
import numpy as np
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_43/898475416.py in <module>
#       1 import numpy as np
# ----> 2 label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])
#
# /tmp/ipykernel_43/898475416.py in <listcomp>(.0)
#       1 import numpy as np
# ----> 2 label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])
#
# ValueError: could not convert string to float:

# %%
# !mkdir train
# !mkdir train/male
# !mkdir train/female

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female

# %%
import shutil 
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male/')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female/')

# %%
import glob
filemale = glob.glob("./train/male/*.*")
filefemale = glob.glob("./train/female/*.*")

# %%
midx = np.random.randint(len(filemale), size = 4)
fidx = np.random.randint(len(filefemale), size = 2)

# %%
for i in fidx:
    shutil.move(filefemale[i],'./test/female/')
for i in midx:
    shutil.move(filemale[i],'./test/male/')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)

# %%
train_dir = './train'
batch_size = 15
img_height = 100 
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 63 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'female': 0, 'male': 1}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph()
    model = Sequential()
    model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape))
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(rate = 0.3))
    model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(rate = 0.2))
    model.add(Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(rate = 0.15))
    model.add(Flatten()) #ตบให้มันเป็นฟีเจอร์เดียวทั้งหมด ละทำดีปเลินนิ่งต่อ
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dropout(rate = 0.15))
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()
fitted_model = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 30)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 7s 1s/step - loss: 1.1408 - accuracy: 0.4892 - val_loss: 0.5460 - val_accuracy: 0.8000
# Epoch 2/30
# 4/4 [==============================] - 6s 2s/step - loss: 0.9230 - accuracy: 0.7244 - val_loss: 0.6135 - val_accuracy: 0.8000
# Epoch 3/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.6212 - accuracy: 0.7577 - val_loss: 0.6594 - val_accuracy: 0.8000
# Epoch 4/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.6267 - accuracy: 0.7439 - val_loss: 0.6549 - val_accuracy: 0.8667
# Epoch 5/30
# 4/4 [==============================] - 5s 969ms/step - loss: 0.6266 - accuracy: 0.8028 - val_loss: 0.6370 - val_accuracy: 0.8000
# Epoch 6/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.5889 - accuracy: 0.7997 - val_loss: 0.6043 - val_accuracy: 0.8000
# Epoch 7/30
# 4/4 [==============================] - 4s 973ms/step - loss: 0.5512 - accuracy: 0.7444 - val_loss: 0.5682 - val_accuracy: 0.8000
# Epoch 8/30
# 4/4 [==============================] - 6s 1s/step - loss: 0.5163 - accuracy: 0.7933 - val_loss: 0.5261 - val_accuracy: 0.8000
# Epoch 9/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.6514 - accuracy: 0.7044 - val_loss: 0.5479 - val_accuracy: 0.8000
# Epoch 10/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.6120 - accuracy: 0.7244 - val_loss: 0.5634 - val_accuracy: 0.8000
# Epoch 11/30
# 4/4 [==============================] - 4s 889ms/step - loss: 0.4154 - accuracy: 0.9013 - val_loss: 0.5308 - val_accuracy: 0.8000
# Epoch 12/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.5369 - accuracy: 0.6861 - val_loss: 0.4667 - val_accuracy: 0.8667
# Epoch 13/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.5036 - accuracy: 0.7859 - val_loss: 0.5340 - val_accuracy: 0.8667
# Epoch 14/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.4668 - accuracy: 0.8244 - val_loss: 0.4988 - val_accuracy: 0.9333
# Epoch 15/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.4966 - accuracy: 0.7244 - val_loss: 0.4474 - val_accuracy: 0.9333
# Epoch 16/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.4371 - accuracy: 0.8008 - val_loss: 0.4060 - val_accuracy: 0.8667
# Epoch 17/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.3168 - accuracy: 0.8458 - val_loss: 0.3555 - val_accuracy: 0.8000
# Epoch 18/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.3524 - accuracy: 0.7986 - val_loss: 0.6919 - val_accuracy: 0.5333
# Epoch 19/30
# 4/4 [==============================] - 6s 1s/step - loss: 0.4319 - accuracy: 0.8489 - val_loss: 0.5325 - val_accuracy: 0.7333
# Epoch 20/30
# 4/4 [==============================] - 6s 1s/step - loss: 0.3169 - accuracy: 0.8778 - val_loss: 0.5353 - val_accuracy: 0.7333
# Epoch 21/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.3590 - accuracy: 0.8489 - val_loss: 0.5447 - val_accuracy: 0.7333
# Epoch 22/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.3622 - accuracy: 0.8120 - val_loss: 0.6775 - val_accuracy: 0.6000
# Epoch 23/30
# 4/4 [==============================] - 4s 1s/step - loss: 0.2904 - accuracy: 0.8656 - val_loss: 0.3956 - val_accuracy: 0.9333
# Epoch 24/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.2238 - accuracy: 0.8674 - val_loss: 0.4333 - val_accuracy: 0.8000
# Epoch 25/30
# 4/4 [==============================] - 6s 2s/step - loss: 0.2452 - accuracy: 0.8424 - val_loss: 0.6419 - val_accuracy: 0.7333
# Epoch 26/30
# 4/4 [==============================] - 4s 831ms/step - loss: 0.2153 - accuracy: 0.8769 - val_loss: 0.6623 - val_accuracy: 0.7333
# Epoch 27/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.1568 - accuracy: 0.9150 - val_loss: 0.5100 - val_accuracy: 0.8000
# Epoch 28/30
# 4/4 [==============================] - 4s 973ms/step - loss: 0.1337 - accuracy: 0.9417 - val_loss: 0.6300 - val_accuracy: 0.6667
# Epoch 29/30
# 4/4 [==============================] - 5s 1s/step - loss: 0.1703 - accuracy: 0.8822 - val_loss: 0.6972 - val_accuracy: 0.7333
# Epoch 30/30
# 4/4 [==============================] - 5s 963ms/step - loss: 0.2443 - accuracy: 0.9094 - val_loss: 0.4272 - val_accuracy: 0.8000

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 1.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
